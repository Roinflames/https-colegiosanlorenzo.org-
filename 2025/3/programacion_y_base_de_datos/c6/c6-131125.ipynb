# %% [markdown]
# # Enriqueciendo Nuestros Datos con IA: Generación de Historias para Personajes de Dragon Ball usando Google Gemini
#
# **Objetivo:** Aprender a utilizar la API de Google Gemini para generar texto creativo y actualizar la base de datos con esta nueva información.
#
# ---

# %% [markdown]
# ## 1. Introducción a la IA Generativa y Google Gemini
#
# La **Inteligencia Artificial Generativa** es una rama de la IA que se enfoca en la creación de contenido nuevo y original, como texto, imágenes, música y más. A diferencia de la IA tradicional que analiza datos existentes, la IA generativa puede producir resultados completamente nuevos.
#
# **Google Gemini** es una familia de modelos de IA generativa de Google que es multimodal, lo que significa que puede entender y procesar diferentes tipos de información como texto, código, imágenes y video.
#
# Para usar la API de Gemini, necesitamos una **API Key**, que es una clave única que nos identifica como usuarios y nos permite acceder a la API.

# %% [markdown]
# ## 2. Obtención de una API Key de Google Gemini
#
# Para obtener tu API Key gratuita, sigue estos pasos:
#
# 1.  Ve a [Google AI Studio](https://aistudio.google.com/).
# 2.  Inicia sesión con tu cuenta de Google.
# 3.  Haz clic en **"Get API key"** en la esquina inferior izquierda.
# 4.  Crea una nueva clave de API en la esquina superior derecha para un proyecto existente o en uno nuevo.
# 5.  Copia tu clave de API. ¡Trátala como una contraseña y no la compartas!
#
# **Importante:** Nunca subas tu clave de API a repositorios públicos como GitHub.

# %% [markdown]
# ## 3. Configuración del Entorno
#
# Primero, instalaremos la librería de Python de Google Gemini.

# %%
# %pip install -q -U google-generativeai 
# %pip install -q python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai
import sqlite3
import os
from dotenv import load_dotenv

# %% [markdown]
# ## 4. Configuración de la API Key
#
# Vamos a configurar la API key de una manera segura. Reemplaza `"YOUR_API_KEY"` con la clave que obtuviste.

# %%
# Cargar variables desde el archivo .env
load_dotenv()

# Leer la API key desde el entorno
API_KEY = os.getenv("GOOGLE_AI_STUDIO_APIKEY")

if not API_KEY:
    raise ValueError("⚠️ No se encontró la variable GOOGLE_API_KEY en el archivo .env")

# Configurar Google Gemini
genai.configure(api_key=API_KEY)
print("✅ API Key cargada y configurada correctamente.")
# Out:
# ✅ API Key cargada y configurada correctamente.

# %% [markdown]
# ## 5. Conexión a la Base de Datos
#
# Nos conectaremos a la base de datos que creamos en la actividad anterior.

# %%
DB_NAME = '../dragonball_characters.db' # Ajusta la ruta si es necesario

try:
    conn = sqlite3.connect(DB_NAME)
    cursor = conn.cursor()
    print(f"Conexión a la base de datos '{DB_NAME}' establecida con éxito.")
except sqlite3.Error as e:
    print(f"Error al conectar a la base de datos: {e}")
# Out:
# Conexión a la base de datos '../dragonball_characters.db' establecida con éxito.

# %% [markdown]
# ## 6. Añadir Nueva Columna a la Tabla
#
# Añadiremos una nueva columna `ai_description` a nuestra tabla `characters` para almacenar el texto generado por la IA.

# %%
try:
    cursor.execute("ALTER TABLE characters ADD COLUMN ai_description TEXT")
    conn.commit()
    print("Columna 'ai_description' añadida a la tabla 'characters'.")
except sqlite3.OperationalError as e:
    if "duplicate column name" in str(e):
        print("La columna 'ai_description' ya existe.")
    else:
        print(f"Error: {e}")
# Out:
# Columna 'ai_description' añadida a la tabla 'characters'.

# %% [markdown]
# ## 7. Obtención de Personajes de la Base de Datos
#
# Obtendremos los nombres y razas de los personajes para crear los prompts.

# %%
cursor.execute("SELECT id, name, race FROM characters")
characters_to_enrich = cursor.fetchall()

# %%
import google.generativeai as genai

for model in genai.list_models():
    if "generateContent" in model.supported_generation_methods:
        print(model.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025

# %% [markdown]
# ## 8. Interactuando con la API de Gemini
#
# Ahora, para cada personaje, crearemos un prompt, llamaremos a la API de Gemini y actualizaremos la base de datos con la historia generada.

# %%
# model = genai.GenerativeModel('gemini-pro')
# model = genai.GenerativeModel("gemini-1.5-flash")
model = genai.GenerativeModel("gemini-2.5-flash")

for char_id, name, race in characters_to_enrich:
    print(f"Generando historia para {name}...")
    prompt = f"Escribe una breve historia creativa y emocionante para el personaje de Dragon Ball llamado {name}, que es de la raza {race}."
    try:
        response = model.generate_content(prompt)
        ai_description = response.text
        cursor.execute("UPDATE characters SET ai_description = ? WHERE id = ?", (ai_description, char_id))
        conn.commit()
        print(f"  -> Historia generada y guardada para {name}.")
    except Exception as e:
        print(f"  -> Error al generar historia para {name}: {e}")

print("\nProceso de enriquecimiento completado.")
# Out:
# Generando historia para Zarbon...
#   -> Historia generada y guardada para Zarbon.
# Generando historia para Dodoria...
#   -> Historia generada y guardada para Dodoria.
# Generando historia para Ginyu...
#   -> Historia generada y guardada para Ginyu.
# Generando historia para Celula...
#   -> Historia generada y guardada para Celula.
# Generando historia para Gohan...
#   -> Historia generada y guardada para Gohan.
#
# Proceso de enriquecimiento completado.

# %% [markdown]
# ## 9. Visualización de los Datos Enriquecidos
#
# Finalmente, consultemos la base de datos para ver los resultados.

# %%
print("--- Personajes con Descripciones de IA ---")
cursor.execute("SELECT name, ai_description FROM characters")
enriched_characters = cursor.fetchall()

for name, ai_desc in enriched_characters:
    print(f"\n**{name}**")
    print(ai_desc)
# Out:
# --- Personajes con Descripciones de IA ---
#
# **Zarbon**
# ¡Absolutamente! Aquí tienes una historia emocionante y un poco introspectiva para Zarbon, imaginándolo como parte de la fría y calculadora raza de Frieza:
#
# ---
#
# **El Sacrificio de la Elegancia**
#
# La nave de combate se deslizó silenciosamente a través del velo púrpura de la nebulosa de Cygnus X-1, su destino: el planeta Xylos-7, una joya verde esmeralda y azul que se negaba a inclinarse ante el Imperio de Frieza. Dentro de la cámara de mando, la figura elegante y esbelta de Zarbon, con su piel verde esmeralda inmaculada y sus largos cabellos aquamarina, observaba la proyección holográfica del mundo rebelde. Sus ojos ámbar, de una belleza inusual, no mostraban más que fría determinación.
#
# Como miembro de la raza de Frieza, Zarbon no solo poseía una fuerza devastadora, sino también una apreciación innata por la perfección, la estrategia y, sobre todo, la estética. Para él, la brutalidad sin gracia era una afrenta; la victoria, un arte.
#
# "Lord Zarbon," la voz monótona de un soldado raso rompió el silencio, "los informes indican una resistencia organizada. Su líder, un tal K’tharr, posee una fuerza considerable para ser un nativo."
#
# Zarbon alzó una mano con un gesto indolente. "Fuerza sin refinamiento es mera potencia bruta, ineficaz ante una mente superior. Prepárense para el desembarco. No deseo que se derrame más sangre de la necesaria… sin un propósito estético, claro."
#
# El desembarco fue un baile mortífero. Zarbon se movía con una gracia letal, sus golpes y patadas eran precisos, cada movimiento una sinfonía de destrucción controlada. Sus ráfagas de energía destrozaban defensas y neutralizaban a los soldados rebeldes con una facilidad desconcertante. El ejército de Xylos-7, acostumbrado a los ataques burdos y caóticos, se desmoronaba ante la combinación de fuerza bruta y maestría marcial de Zarbon.
#
# Pero entonces, apareció K’tharr. El líder nativo era una mole de músculos endurecidos, de piel rocosa y cuernos afilados, empuñando un arma ancestral que crepitaba con energía elemental. K’tharr no era elegante, no era estratégico; era pura fuerza de voluntad y desesperación.
#
# El combate entre Zarbon y K’tharr fue un choque de mundos. La velocidad cegadora y los ataques calculados de Zarbon se encontraron con la resistencia inquebrantable y los golpes devastadores del líder de Xylos. Zarbon esquivaba con desdén, contraatacaba con precisión, disfrutando del desafío de someter a una bestia tan obstinada. Podía haberlo aniquilado en segundos con su poder completo, pero le gustaba saborear la victoria.
#
# Sin embargo, K’tharr era más persistente de lo que Zarbon había anticipado. Cada vez que Zarbon pensaba que el nativo estaba acabado, K’tharr se levantaba de nuevo, sus ojos inyectados en sangre, impulsado por una fiera lealtad a su mundo. Un golpe brutal del arma de K’tharr rozó el hombro de Zarbon, arrancándole un grito de molestia y una fina línea de sangre esmeralda. Su impecable rostro se contrajo.
#
# "¡Insolente!" siseó Zarbon, su voz cargada de una ira fría. "Has osado manchar mi perfección."
#
#
# "¡Qué patraña!", gruñó Dodoria a sí mismo, su voz áspera resonando en la cabina. "¿Artefactos? ¿Leyendas? ¡Prefiero pulverizar mundos y escuchar los gritos!"
#
# Al aterrizar en la superficie rocosa de Kryll, una atmósfera pesada y pegajosa se aferró a su armadura. El aire era denso, de un tono carmesí oscuro, y extrañas formaciones cristalinas brotaban del suelo como dientes afilados. La única luz provenía de una luna lejana, bañando el paisaje en un brillo púrpura fantasmal.
#
# Su rastreador detectó una enorme concentración de energía a kilómetros de distancia. El artefacto, sin duda. Dodoria sonrió, revelando sus colmillos. "Hora de un paseo, perdedores", murmuró, encendiendo su aura de ki y despegando a toda velocidad.
#
# Al llegar a una meseta elevada, encontró lo que buscaba: un altar rudimentario de rocas oscuras, y sobre él, un cristal pulsante que irradiaba una energía extraña y cautivadora. Era más grande de lo que esperaba, y vibraba con una melodía silenciosa que le erizaba el vello.
#
# Pero antes de que pudiera acercarse, el suelo a su alrededor cobró vida. Las formaciones cristalinas se desprendieron con un chirrido agudo, transformándose en criaturas esqueléticas y translúcidas, con extremidades dentadas y ojos de un brillo frío. No tenían rostro, solo una intención depredadora que Dodoria sintió con un escalofrío.
#
# "¡¿Qué demonios son ustedes?!" rugió Dodoria, disparando una ráfaga de ki que pulverizó a tres de ellas. Sin embargo, los fragmentos de cristal se reformaron en el aire, no solo regenerándose, sino ¡multiplicándose! Ahora había el doble de enemigos.
#
# Las criaturas se abalanzaron, ágiles y numerosas. Sus ataques no eran fuertes individualmente, pero eran punzantes y lograban pasar sus defensas, drenando su energía con cada toque. Dodoria, acostumbrado a enfrentarse a oponentes que simplemente estallaban, se encontró con una pesadilla viviente. Sus ráfagas de ki, que normalmente pulverizaban asteroides, apenas los hacían retroceder. Se fragmentaban, sí, pero cada pedazo se reformaba, a veces en entidades más pequeñas y aún más rápidas.
#
# "¡Insolentes insectos!" gritó, girando y golpeando con sus puños y codos con púas, aplastando docenas a la vez. El suelo se cubrió de polvo de cristal, pero el enjambre no hacía más que crecer, acercándose al artefacto.
#
# El pánico, una emoción que Dodoria rara vez se permitía, comenzaba a roerle los bordes de su brutal confianza. Si no traía el artefacto, Frieza lo haría pedazos. Si se quedaba, estas cosas lo consumirían lentamente hasta que no quedara nada. Estaba atrapado.
#
# Entonces, una idea brutal y desesperada se formó en su mente. Miró el cristal pulsante en el altar. Su energía era inmensa. Si no podía derrotar a estas cosas de uno en uno, tendría que cambiar el campo de juego.
#
# Con un rugido primario que no era de batalla, sino de pura frustración y desesperación, Dodoria se elevó unos metros. El aire a su alrededor comenzó a vibrar con una intensidad aterradora. Las criaturas cristalinas se detuvieron, sus ojos fríos ahora mostrando un atisbo de algo parecido al miedo.
#
# Dodoria concentró cada gramo de su energía restante en una sola esfera masiva de ki carmesí, tan densa que el aire a su alrededor crujió. Era su técnica más poderosa, una que usaba para borrar continentes enteros. La lanzó directamente hacia el altar, no para destruir el artefacto, sino para desatar su energía contenida.
#
# La explosión fue cataclísmica. Una onda de choque de energía pura barrió la meseta, pulverizando las criaturas cristalinas en una lluvia de polvo brillante y fragmentando el propio altar. El cristal pulsante, despojado de su base, flotó ingrávido por un instante, su energía ahora descontrolada, creando una vorágine de poder.
#
# Aprovechando el caos y la disipación momentánea de sus enemigos, Dodoria se lanzó hacia el artefacto. Sus manos enguantadas se cerraron sobre él, sintiendo una corriente fría y extraña recorrer su cuerpo. Las criaturas restantes, aunque diezmadas, comenzaban a reformarse, atraídas por la energía liberada.
#
# Sin mirar atrás, Dodoria ascendió con el artefacto en mano, su nave de ataque ya encendida y lista para el despegue. La explosión había abierto un agujero en la niebla carmesí, y vio cómo el planeta se cubría nuevamente de nuevos cristales, listos para reiniciar el ciclo de la pesadilla.
#
# Horas después, a bordo de la nave insignia de Frieza, Dodoria presentó el cristal. Estaba exhausto, su armadura abollada y su piel aún hormigueando por los efectos de los ataques.
#
# "¿El artefacto está intacto?", preguntó Frieza con su voz helada, sin siquiera mirarlo, mientras uno de sus científicos tomaba el cristal con cautela.
#
# "Sí, Lord Frieza. Fue... una operación complicada", respondió Dodoria, tratando de sonar indiferente.
#
# Frieza solo asintió con un gesto apenas perceptible. "Bien. Ahora desaparece".
#
# Dodoria hizo una reverencia y se retiró. El terror de Kryll aún palpitaba en sus venas, un recordatorio de que incluso un brutal ejecutor podía encontrar su propio infierno personal. Pero en lugar de quebrarlo, lo había endurecido. La próxima vez, se aseguraría de que el sufrimiento de otros fuera aún mayor. La experiencia solo había alimentado su sadismo.
#
# **Ginyu**
# Aquí tienes una historia creativa y emocionante para Ginyu:
#
# ---
#
# **El Eco del Engaño en Kharon-7**
#
# El Capitán Ginyu, con su postura impecable y la confianza inherente a su linaje de la raza Frieza, inspeccionaba las ruinas humeantes de la base rebelde en Kharon-7. Su misión era simple: erradicar cualquier vestigio de resistencia y confiscar un raro cristal de energía, el "Ojo de Zephyr", para el Señor Frieza. A su lado, los leales Guldo, Recoome, Burter y Jeice estaban en alerta, pero Ginyu sentía una irritante falta de desafío.
#
# "¡Demasiado fácil!", bramó Ginyu, ejecutando una pose dramática. "La debilidad es un insulto a mi grandeza. ¿Dónde está el peligro? ¿La intriga? ¡El mero hecho de que me envíen a una misión tan trivial es una afrenta!"
#
# Un gruñido bajo rompió el silencio. No venía de sus hombres, sino de las sombras entre los restos metálicos. Un ser corpulento y angular, de piel azul oscura y múltiples ojos rojos, emergió. Era Tharrus, un cazarrecompensas notorio, conocido por su brutalidad y su inmunidad parcial a las habilidades psíquicas.
#
# "El Capitán Ginyu", dijo Tharrus con una voz rasposa, sus ojos escaneando al guerrero de la raza Frieza. "Mi cliente paga bien por cabezas como la tuya. Y cuerpos."
#
# Ginyu sonrió con desdén. "¿Un simple mortal cree que puede medirse con el Capitán Ginyu? ¡Qué presunción!"
#
# La batalla fue veloz y brutal. Tharrus, sorprendentemente fuerte y ágil, logró esquivar varios de los ataques coordinados de las Fuerzas Ginyu. Su piel parecía desviar los ataques de energía, y su fuerza física era aterradora. Recoome, el más robusto, se vio momentáneamente superado.
#
# El Saiyajin se transformó en su estado definitivo, el *Gohan Bestia*. Su cabello blanco se erizó, sus ojos brillaron con un aura violácea. Pero esta vez, no era solo ira lo que lo impulsaba. Era la voluntad inquebrantable de proteger, la serena determinación de un guardián que ha comprendido su propósito.
#
# La batalla que siguió no fue solo un choque de puños. La Sombra intentó manipularlo, proyectando ilusiones de un futuro donde Pan o Videl sufrían por su falta de acción, o donde él se convertía en un monstruo de batalla. Gohan las disipaba con la concentración de un monje, su mente un bastión inquebrantable. Cada golpe que asestaba no era solo fuerza bruta, sino una expulsión de su propia voluntad pura, su rechazo a la desesperación.
#
# "¡No soy un guerrero por la gloria, sino un guardián por la paz!", rugió, y su voz resonó con la autoridad de un dios. La Sombra, que se alimentaba de la negatividad, se tambaleó ante la abrumadora positividad y resolución de Gohan. Intentó absorber su ki, pero la energía de Gohan era tan pura, tan imbuida de su amor y propósito, que la Sombra no podía asimilarla sin quemarse.
#
# Con un grito final que perforó los cielos, Gohan concentró todo su poder. No era un ataque impulsado por la rabia ciega, sino un Kamehameha definitivo, cargado con la esencia de su ser: el intelecto del erudito, la fuerza del Saiyajin, y el amor incondicional del padre y esposo. La onda de energía blanca y violeta no solo golpeó a la Sombra, sino que la purificó. No la destruyó, sino que la desintegró en partículas de luz, liberando las almas atrapadas y restaurando la paz en los corazones.
#
# El cielo se aclaró. Gohan regresó a su forma base, agotado pero sereno. Miró a su familia, que ahora dormía en paz, sus pesadillas disipadas. Había vuelto a luchar, no porque lo deseara, sino porque la vida que amaba lo exigía. El erudito había despertado al guerrero, no como una renuncia a su yo pacífico, sino como la extensión máxima de su deber.
#
# Al día siguiente, mientras resolvía ecuaciones con una sonrisa y Pan jugaba a sus pies, Gohan supo que la verdadera fuerza no residía solo en el poder desatado, sino en la sabiduría para cuándo usarlo, y en la voluntad para proteger aquello que se valora por encima de todo. El Saiyajin de corazón puro, el erudito del universo, había encontrado el equilibrio perfecto. Y la Tierra volvió a respirar en paz, sin saber que su silencio había sido un sacrificio silencioso de su guardián más inesperado.

# %% [markdown]
# ## 10. Conclusión y Próximos Pasos
#
# ¡Felicidades! Has aprendido a:
# - Conectar con una API de IA generativa (Google Gemini).
# - Crear prompts para generar texto creativo.
# - Enriquecer una base de datos existente con datos generados por IA.
#
# **Ideas para Próximos Pasos:**
# - **Generación de Imágenes:** Usar un modelo de texto a imagen para crear retratos de los personajes.
# - **Análisis de Sentimientos:** Analizar las descripciones originales para determinar el sentimiento (positivo, negativo, neutral).
# - **Chatbot de Personajes:** Crear un chatbot que responda como si fuera un personaje de Dragon Ball.

# %%
if conn:
    conn.close()
    print("\nConexión a la base de datos cerrada.")
# Out:
# Conexión a la base de datos cerrada.

# %% [markdown]
# Si quieres hacerlo dinámico y que use siempre el modelo más reciente compatible, puedes listar los modelos y filtrar automáticamente uno válido:

# %%
available_models = [m.name for m in genai.list_models() if "generateContent" in m.supported_generation_methods]
model_name = next((m for m in available_models if "gemini-2.5-flash" in m), "gemini-2.5-pro")
model = genai.GenerativeModel(model_name)
print(f"✅ Usando modelo: {model_name}")
